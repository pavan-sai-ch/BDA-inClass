# %%
import numpy as np
import pandas as pd

# %%
#Creating a DataFrame from a given dictionary
data = {
    'ID': np.arange(1, 1000001),  # 1 million IDs
    'Value': np.random.rand(1000000),  # 1 million random values
    'Category': np.random.choice(['A', 'B', 'C', 'D'], size=1000000)
}  # Random categories
df = pd.DataFrame(data)
df
# Out:
#              ID     Value Category
# 0             1  0.915496        B
# 1             2  0.881498        C
# 2             3  0.688591        B
# 3             4  0.757857        D
# 4             5  0.767474        A
# ...         ...       ...      ...
# 999995   999996  0.790266        B
# 999996   999997  0.065344        D
# 999997   999998  0.049669        A
# 999998   999999  0.730091        A
# 999999  1000000  0.995579        D
#
# [1000000 rows x 3 columns]

# %%
#output first 10 rows
df.head(10)
# Out:
#    ID     Value Category
# 0   1  0.915496        B
# 1   2  0.881498        C
# 2   3  0.688591        B
# 3   4  0.757857        D
# 4   5  0.767474        A
# 5   6  0.889045        C
# 6   7  0.255441        D
# 7   8  0.086456        B
# 8   9  0.577601        A
# 9  10  0.689718        C

# %%
df['Value'] #Access a column “Value”
# Out:
# 0         0.915496
# 1         0.881498
# 2         0.688591
# 3         0.757857
# 4         0.767474
#             ...
# 999995    0.790266
# 999996    0.065344
# 999997    0.049669
# 999998    0.730091
# 999999    0.995579
# Name: Value, Length: 1000000, dtype: float64

# %%
df.rename(columns={'ID': 'ID number', 'Value': 'Random Value', 'Category': 'Choice'}, inplace=True)
df.head(5)
#Modify columns in the DataFrame with names (ID number, Random value, Choice) and show output
#for first five rows
# Out:
#    ID number  Random Value Choice
# 0          1      0.915496      B
# 1          2      0.881498      C
# 2          3      0.688591      B
# 3          4      0.757857      D
# 4          5      0.767474      A

# %%
pd.set_option('display.max_rows', None)
#pd. set _option('display-max_columns', None)
student_data = pd.DataFrame({
    'school_code': ['s001', 's002', 's003', 's001', 's002', 's004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco', 'Gino Mcneill', 'Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_Of_Birth': ['15/05/2002', '17/05/2002', '16/02/1999', '25/09/1998', '11/05/2002', '15/09/1997'],
    'age': [12, 12, 13, 13, 14, 12],
    'height': [173, 192, 186, 167, 151, 159],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4'],
    'index': ['S1', 'S2', 'S3', 'S4', 'S5', 'S6']
})

print("Original DataFrame:")
print(student_data)
print('\nSplit the said data on school_code, class wise:')
result = student_data.groupby(['school_code', 'class'])
for name, group in result:
    print("\nGroup:")
    print(name)
    print(group)
# Out:
# Original DataFrame:
#   school_code class            name date_Of_Birth  age  height  weight  \
# 0        s001     V  Alberto Franco    15/05/2002   12     173      35
# 1        s002     V    Gino Mcneill    17/05/2002   12     192      32
# 2        s003    VI     Ryan Parkes    16/02/1999   13     186      33
# 3        s001    VI    Eesha Hinton    25/09/1998   13     167      30
# 4        s002     V    Gino Mcneill    11/05/2002   14     151      31
# 5        s004    VI    David Parkes    15/09/1997   12     159      32
#
#    address index
# 0  street1    S1
# 1  street2    S2
# 2  street3    S3
# 3  street1    S4
# 4  street2    S5
# 5  street4    S6
#
# Split the said data on school_code, class wise:
#
# Group:
# ('s001', 'V')
#   school_code class            name date_Of_Birth  age  height  weight  \
# 0        s001     V  Alberto Franco    15/05/2002   12     173      35
#
#    address index
# 0  street1    S1
#
# Group:
# ('s001', 'VI')
# ...

# %%
data_csv = pd.read_csv('./datasets_ICP4/data.csv')
data_csv #Read the provided CSV file ‘data.csv’
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
data_csv.describe() #Show the basic statistical description about the data.
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
data_csv.isnull().sum()#check null values
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
data_csv['Calories'] = data_csv['Calories'].fillna(data_csv['Calories'].mean())
data_csv.isnull().sum() #replace null values
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
data_csv[['Calories', 'Duration']].agg(['min', 'max', 'count', 'mean']) #using agg func
# Out:
#           Calories    Duration
# min      50.300000   15.000000
# max    1860.400000  300.000000
# count   169.000000  169.000000
# mean    375.790244   63.846154

# %%
data_csv[(data_csv['Calories'] >= 500) & (data_csv['Calories'] <= 1000)] #filter
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 51         80    123       146     643.1
# 62        160    109       135     853.0
# 65        180     90       130     800.4
# 66        150    105       135     873.4
# 67        150    107       130     816.0
# 72         90    100       127     700.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 78        120    100       130     500.4
# 83        120    100       130     500.0
# 90        180    101       127     600.1
# 99         90     93       124     604.1
# 101        90     90       110     500.0
# 102        90     90       100     500.0
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
data_csv[(data_csv['Calories'] > 500) & (data_csv['Pulse'] < 100)]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 65        180     90       130     800.4
# 70        150     97       129    1115.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
df_modified = data_csv.drop('Maxpulse', axis=1)
df_modified #new df with drop
# Out:
#      Duration  Pulse     Calories
# 0          60    110   409.100000
# 1          60    117   479.000000
# 2          60    103   340.000000
# 3          45    109   282.400000
# 4          45    117   406.000000
# 5          60    102   300.000000
# 6          60    110   374.000000
# 7          45    104   253.300000
# 8          30    109   195.100000
# 9          60     98   269.000000
# 10         60    103   329.300000
# 11         60    100   250.700000
# 12         60    106   345.300000
# 13         60    104   379.300000
# 14         60     98   275.000000
# 15         60     98   215.200000
# 16         60    100   300.000000
# 17         45     90   375.790244
# 18         60    103   323.000000
# 19         45     97   243.000000
# 20         60    108   364.200000
# 21         45    100   282.000000
# 22         60    130   300.000000
# 23         45    105   246.000000
# 24         60    102   334.500000
# 25         60    100   250.000000
# ...

# %%
data_csv.drop('Maxpulse', axis=1, inplace=True)
data_csv #dropping from main df
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# 5          60    102     300.0
# 6          60    110     374.0
# 7          45    104     253.3
# 8          30    109     195.1
# 9          60     98     269.0
# 10         60    103     329.3
# 11         60    100     250.7
# 12         60    106     345.3
# 13         60    104     379.3
# 14         60     98     275.0
# 15         60     98     215.2
# 16         60    100     300.0
# 17         45     90       NaN
# 18         60    103     323.0
# 19         45     97     243.0
# 20         60    108     364.2
# 21         45    100     282.0
# 22         60    130     300.0
# 23         45    105     246.0
# 24         60    102     334.5
# 25         60    100     250.0
# 26         60     92     241.0
# 27         60    103       NaN
# 28         60    100     280.0
# ...

# %%
data_csv = data_csv.dropna(subset=['Calories']).copy()  # Force a real copy
data_csv.loc[:, 'Calories'] = data_csv['Calories'].astype(int)
data_csv.dtypes#convert data type
# Out:
# Duration    int64
# Pulse       int64
# Calories    int64
# dtype: object

# %%
import matplotlib.pyplot as plt

data_csv.plot.scatter(x='Duration', y='Calories', title='Scatter Plot: Duration vs Calories')
plt.show() #scatter plot
